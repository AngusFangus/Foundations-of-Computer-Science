# %% [markdown]
# ## Foundations of Computer Science
#
# ### Marco Ferrario 795203

# %%
import numpy as np
import pandas as pd
import random
import time

# %%
start = time.time()

# %%
loans = pd.read_csv("loans.csv")

# %%
lenders = pd.read_csv("lenders.csv")

# %%
loans_lenders = pd.read_csv("loans_lenders.csv")

# %% [markdown]
# ### 1) Normalize the loan_lenders table. In the normalized table, each row must have one loan_id and one lender.

# %%
loans_lenders
# Out:
#          loan_id                                            lenders
# 0         483693  muc888, sam4326, camaran3922, lachheb1865, reb...
# 1         483738  muc888, nora3555, williammanashi, barbara5610,...
# 2         485000  muc888, terrystl, richardandsusan8352, sherri4...
# 3         486087  muc888, james5068, rudi5955, daniel9859, don92...
# 4         534428  muc888, niki3008, teresa9174, mike4896, david7...
# ...          ...                                                ...
# 1387427   678999  michael43411218, carol5987, gooddogg1, chris41...
# 1387428  1207353  rjhoward1986, jeffrey6870, trolltech4460, elys...
# 1387429  1206220  vicky7746, gooddogg1, fairspirit, craig9729960...
# 1387430  1206425  rich6705, sergiiy9766, angela7509, barbara5610...
# 1387431  1206486                              alan5175, amy38101311
#
# [1387432 rows x 2 columns]

# %% [markdown]
# Per normalizzare la tabella loans_lenders si utilizzano ```str.split``` ed ```explode```.

# %%
#punto 1 modo b
loans_lenders = loans_lenders.assign(lenders=loans_lenders.lenders.str.split(',')).explode('lenders').reset_index(drop=True)

# %% [markdown]
# Controllo il numero di valori unici per `loan_id` e `lenders`.

# %%
loans_lenders.loan_id.nunique()
# Out:
# 1387432

# %%
loans_lenders.lenders.nunique()
# Out:
# 1639026

# %% [markdown]
# La tabella normalizzata contiene alcune righe duplicate, questo perchè alcune persone hanno partecipato più volte allo stesso prestito.

# %%
duplicateRowsDF = loans_lenders[loans_lenders.duplicated()]
 
print("Righe duplicate del dataset:")
print(duplicateRowsDF)
# Out:
# Righe duplicate del dataset:
#           loan_id        lenders
# 45         483738   danhostetler
# 46         483738   danhostetler
# 121        563395   motoharu1020
# 128        575414     dougal1825
# 152        578029       paul1853
# ...           ...            ...
# 28293582  1204948           yipe
# 28293595  1204948     jordan2934
# 28293703  1187825       hans8594
# 28293704  1187825       hans8594
# 28293705  1187825       hans8594
#
# [796126 rows x 2 columns]

# %%
loans_lenders.isnull().sum()
# Out:
# loan_id    0
# lenders    0
# dtype: int64

# %% [markdown]
# Elimino i duplicati.

# %%
loans_lenders_unique = loans_lenders.drop_duplicates()

# %%
loans_lenders_unique
# Out:
#           loan_id             lenders
# 0          483693              muc888
# 1          483693             sam4326
# 2          483693         camaran3922
# 3          483693         lachheb1865
# 4          483693         rebecca3499
# ...           ...                 ...
# 28293926  1206425   trogdorfamily7622
# 28293927  1206425           danny6470
# 28293928  1206425             don6118
# 28293929  1206486            alan5175
# 28293930  1206486         amy38101311
#
# [27497805 rows x 2 columns]

# %% [markdown]
# ### 2) For each loan, add a column duration corresponding to the number of days between the disburse time and the planned expiration time. If any of those two dates is missing, also the duration must be missing.

# %%
#punto 2
loans['disburse_time'] = pd.to_datetime(loans['disburse_time'])
loans['planned_expiration_time'] = pd.to_datetime(loans['planned_expiration_time'])

loans['disburse_date'] = loans['disburse_time'].dt.date
loans['planned_expiration_date'] = loans['planned_expiration_time'].dt.date

# %% [markdown]
# Attraverso le funzioni `to_date` e `to_datetime` è possibile effettuare la differenza tra le colonne in esame.

# %%
loans['duration'] = loans['planned_expiration_date'] - loans['disburse_date']

# %%
loans[['disburse_time','planned_expiration_time','duration']].isnull().sum()
# Out:
# disburse_time                2813
# planned_expiration_time    371834
# duration                   374645
# dtype: int64

# %% [markdown]
# Verifica della quantià dei missing. Si nota che due righe presentano valori mancanti sia per `disburse_time` che per `planned_expiration_time`.

# %%
loans['duration']
# Out:
# 0         54 days
# 1         96 days
# 2         37 days
# 3         35 days
# 4         58 days
#             ...
# 1419602   40 days
# 1419603   39 days
# 1419604   51 days
# 1419605   63 days
# 1419606   61 days
# Name: duration, Length: 1419607, dtype: timedelta64[ns]

# %% [markdown]
# Si osserva che la durata media è di 51 giorni, con un massimo di 1674 giorni.

# %%
loans['duration'].describe()
# Out:
# count                    1044962
# mean     51 days 19:56:30.592959
# std      29 days 14:51:03.489556
# min          -138 days +00:00:00
# 25%             42 days 00:00:00
# 50%             52 days 00:00:00
# 75%             62 days 00:00:00
# max           1674 days 00:00:00
# Name: duration, dtype: object

# %% [markdown]
# ### 3) Find the lenders that have funded at least twice.

# %%
#punto 3
lenders_names = loans_lenders.groupby(['lenders'], as_index=False).count()
lenders_twice = lenders_names.loc[(lenders_names['loan_id'] >= 2)]
lenders_twice
# Out:
#                  lenders  loan_id
# 0                    000       39
# 1                  00000       39
# 2                   0002       70
# 4         0101craign0101       71
# 5                0132575        4
# ...                  ...      ...
# 1639018           zyrorl        3
# 1639020           zzaman       11
# 1639021          zzanita        2
# 1639024         zzmcfate       56
# 1639025       zzrvmf8538        2
#
# [1005111 rows x 2 columns]

# %% [markdown]
# Dopo aver raggruppato per `lenders` si selezionano quelli che hanno effettuato almeno due prestiti, risultati 1005111.

# %% [markdown]
# ### 4) For each country, compute how many loans have involved that country as borrowers.

# %%
#punto 4
pd.set_option('display.max_columns', 500)
loans[0:10000]
# Out:
#       loan_id        loan_name original_language  \
# 0      657307             Aivy           English
# 1      657259   Idalia Marizza           Spanish
# 2      658010            Aasia           English
# 3      659347          Gulmira           Russian
# 4      656933          Ricky\t           English
# ...       ...              ...               ...
# 9995   996964  Pauline's Group           English
# 9996   997380   Amivi massanvi            French
# 9997   997880          Mariamu           English
# 9998   993127         ESTELITA           English
# 9999   998830         WELMINCE           English
#
#                                             description  \
# 0     Aivy, 21 years of age, is single and lives in ...
# 1     Doña Idalia, esta casada, tiene 57 años de eda...
# 2     Aasia is a 45-year-old married lady and she ha...
# 3     Гулмире 36 лет, замужем, вместе с супругом вос...
# 4     Ricky is a farmer who currently cultivates his...
# ...                                                 ...
# 9995  Pauline is a 42-year-old, proud mother of six ...
# 9996  \nMariée et mère de deux enfants, Amivi est un...
# 9997  Mariamu is 27 years old, and she is currently ...
# 9998  Estelita is 52 years old with one child with h...
# 9999  Welmince is a 34-year-old woman married to Ale...
#
#                                  description_translated  funded_amount  \
# 0                                                   NaN          125.0
# 1     Idalia, 57, is married and lives with her husb...          400.0
# 2                                                   NaN          400.0
# 3     Gulmira is 36 years old and married.  She and ...          625.0
# 4                                                   NaN          425.0
# ...                                                 ...            ...
# 9995  Pauline is a 42-year-old, proud mother of six ...          350.0
# 9996  The married mother of two, Amivi is 33 years o...          150.0
# 9997  Mariamu is 27 years old, and she is currently ...          950.0
# 9998  Estelita is 52 years old with one child with h...          650.0
# 9999  Welmince is a 34-year-old woman married to Ale...          225.0
#
#       loan_amount  status                 activity_name  sector_name  \
# 0           125.0  funded                 General Store       Retail
# 1           400.0  funded                 Used Clothing     Clothing
# 2           400.0  funded                 General Store       Retail
# 3           625.0  funded                       Farming  Agriculture
# 4           425.0  funded                       Farming  Agriculture
# ...           ...     ...                           ...          ...
# 9995        350.0  funded                       Farming  Agriculture
# 9996        150.0  funded  Cloth & Dressmaking Supplies       Retail
# 9997        950.0  funded                     Beverages         Food
# 9998        650.0  funded                 General Store       Retail
# 9999        225.0  funded                 General Store       Retail
#
#                                                loan_use country_code  \
# 0      to buy additional inventories for her sari-sa...           PH
# 1     To buy American clothing such as blouses, shir...           HN
# 2                 to buy stock of rice, sugar and flour           PK
# 3     to buy cucumber and tomato seeds, as well as f...           KG
# 4      to buy organic fertilizer and agrochemical pr...           PH
# ...                                                 ...          ...
# 9995  to purchase a solar light and gain access to c...           KE
# 9996           to purchase 8 lengths of 'pagne' fabrics           TG
# 9997       to add more drinks for her business to sell.           TZ
# 9998  to buy canned goods, cooking oil, sugar, coffe...           PH
# 9999  to buy more stocks such as sugar, rice and veg...           ID
#
#      country_name                       town_name currency_policy  \
# 0     Philippines            Ozamiz - Ozamiz City          shared
# 1        Honduras               La Lopez, Choloma          shared
# 2        Pakistan                       Lala Musa          shared
# 3      Kyrgyzstan      Aravan village, Osh region          shared
# 4     Philippines  Baleleng, Sto. Thomas, Isabela          shared
# ...           ...                             ...             ...
# 9995        Kenya                   Bungoma South          shared
# 9996         Togo                          Tokoin          shared
# 9997     Tanzania                    Handeni Town          shared
# 9998  Philippines      San Andres Aurora, Isabela          shared
# 9999    Indonesia                             NaN          shared
#
#       currency_exchange_coverage_rate currency  partner_id  \
# 0                                 0.1      PHP       126.0
# 1                                 0.1      HNL       201.0
# 2                                 0.1      PKR       245.0
# 3                                 0.1      KGS       171.0
# 4                                 0.1      PHP       123.0
# ...                               ...      ...         ...
# 9995                              0.1      KES       202.0
# 9996                              0.1      XOF       296.0
# 9997                              0.1      TZS       379.0
# 9998                              0.1      PHP       123.0
# 9999                              0.1      IDR       129.0
#
#                         posted_time   planned_expiration_time  \
# 0     2014-01-15 02:23:45.000 +0000 2014-02-14 03:30:06+00:00
# 1     2014-01-14 20:23:20.000 +0000 2014-03-26 22:25:07+00:00
# 2     2014-01-16 11:32:58.000 +0000 2014-02-15 21:10:05+00:00
# 3     2014-01-20 09:59:48.000 +0000 2014-02-21 03:10:02+00:00
# 4     2014-01-14 05:46:21.000 +0000 2014-02-13 06:10:02+00:00
# ...                             ...                       ...
# 9995  2015-12-18 02:33:26.000 +0000 2016-01-20 17:20:13+00:00
# 9996  2015-12-18 16:07:27.000 +0000 2016-01-24 00:50:04+00:00
# 9997  2015-12-20 14:51:25.000 +0000 2016-01-21 15:50:03+00:00
# 9998  2015-12-10 14:09:32.000 +0000 2016-01-20 15:50:03+00:00
# 9999  2015-12-22 08:35:35.000 +0000 2016-01-22 20:00:03+00:00
#
#                  disburse_time                    raised_time  lender_term  \
# 0    2013-12-22 08:00:00+00:00  2014-01-15 04:48:22.000 +0000          7.0
# 1    2013-12-20 08:00:00+00:00  2014-02-25 06:42:06.000 +0000          8.0
# 2    2014-01-09 08:00:00+00:00  2014-01-24 23:06:18.000 +0000         14.0
# 3    2014-01-17 08:00:00+00:00  2014-01-22 05:29:28.000 +0000         14.0
# 4    2013-12-17 08:00:00+00:00  2014-01-14 17:29:27.000 +0000          7.0
# ...                        ...                            ...          ...
# 9995 2016-02-01 08:00:00+00:00  2015-12-23 15:38:46.000 +0000         11.0
# 9996 2015-12-04 08:00:00+00:00  2015-12-25 02:51:17.000 +0000          7.0
# 9997 2015-11-20 08:00:00+00:00  2015-12-23 20:15:57.000 +0000         14.0
# 9998 2015-11-11 08:00:00+00:00  2015-12-22 09:13:10.000 +0000          7.0
# 9999 2015-11-25 08:00:00+00:00  2015-12-26 14:10:55.000 +0000         14.0
#
#       num_lenders_total  num_journal_entries  num_bulk_entries  \
# 0                     3                    2                 1
# 1                    11                    2                 1
# 2                    16                    2                 1
# 3                    21                    2                 1
# 4                    15                    2                 1
# ...                 ...                  ...               ...
# 9995                 14                    2                 2
# 9996                  5                    1                 1
# 9997                 10                    2                 1
# 9998                 24                    1                 1
# 9999                  6                    1                 1
#
#                                                    tags  \
# 0                                                   NaN
# 1                                                   NaN
# 2     #Woman Owned Biz, #Supporting Family, user_fav...
# 3                                         user_favorite
# 4              #Animals, #Eco-friendly, #Sustainable Ag
# ...                                                 ...
# 9995                                                NaN
# 9996                                                NaN
# 9997                                      user_favorite
# 9998                                                NaN
# 9999                                                NaN
#
#                                        borrower_genders  \
# 0                                                female
# 1                                                female
# 2                                                female
# 3                                                female
# 4                                                  male
# ...                                                 ...
# 9995  female, female, female, male, male, female, fe...
# 9996                                             female
# 9997                                             female
# 9998                                             female
# 9999                                             female
#
#                                    borrower_pictured repayment_interval  \
# 0                                               true          irregular
# 1                                               true            monthly
# 2                                               true            monthly
# 3                                               true            monthly
# 4                                               true             bullet
# ...                                              ...                ...
# 9995  true, true, true, true, true, true, true, true             bullet
# 9996                                            true          irregular
# 9997                                            true            monthly
# 9998                                            true          irregular
# 9999                                            true          irregular
#
#      distribution_model disburse_date planned_expiration_date duration
# 0         field_partner    2013-12-22              2014-02-14  54 days
# 1         field_partner    2013-12-20              2014-03-26  96 days
# 2         field_partner    2014-01-09              2014-02-15  37 days
# 3         field_partner    2014-01-17              2014-02-21  35 days
# 4         field_partner    2013-12-17              2014-02-13  58 days
# ...                 ...           ...                     ...      ...
# 9995      field_partner    2016-02-01              2016-01-20 -12 days
# 9996      field_partner    2015-12-04              2016-01-24  51 days
# 9997      field_partner    2015-11-20              2016-01-21  62 days
# 9998      field_partner    2015-11-11              2016-01-20  70 days
# 9999      field_partner    2015-11-25              2016-01-22  58 days
#
# [10000 rows x 34 columns]

# %%
loans['country_name'].isnull().sum()
# Out:
# 0

# %%
loans['loan_id'].nunique()
# Out:
# 1419607

# %%
loans['country_name'].value_counts()
# Out:
# Philippines         285336
# Kenya               143699
# Peru                 86000
# Cambodia             79701
# El Salvador          64037
#                      ...
# Mauritania               1
# Botswana                 1
# Uruguay                  1
# Papua New Guinea         1
# Canada                   1
# Name: country_name, Length: 96, dtype: int64

# %% [markdown]
# Attraverso la funzione `value_count` si osservano i prestiti effettuati per ogni stato. Si osserva che le Filippine ne hanno ricevuti la quantità maggiore.

# %%
loans['country_name'].value_counts().describe()
# Out:
# count        96.000000
# mean      14787.572917
# std       34997.602451
# min           1.000000
# 25%         477.500000
# 50%        4667.500000
# 75%       15110.500000
# max      285336.000000
# Name: country_name, dtype: float64

# %% [markdown]
# ### 5) For each country, compute the overall amount of money borrowed

# %%
#punto 5
loans[['loan_amount']].isnull().sum()
# Out:
# loan_amount    0
# dtype: int64

# %%
loans[['country_name']].isnull().sum()
# Out:
# country_name    0
# dtype: int64

# %%
total_amount = loans.groupby('country_name', as_index=False)['loan_amount'].sum()
total_amount
# Out:
#       country_name  loan_amount
# 0      Afghanistan    1967950.0
# 1          Albania    4307350.0
# 2          Armenia   22950475.0
# 3       Azerbaijan   14784625.0
# 4           Belize     150175.0
# ..             ...          ...
# 91         Vietnam   24681100.0
# 92  Virgin Islands      10000.0
# 93           Yemen    3444000.0
# 94          Zambia    1978975.0
# 95        Zimbabwe    5851875.0
#
# [96 rows x 2 columns]

# %% [markdown]
# Viene effettuato un raggruppamento per `country_name` e sommato il valore del prestito.

# %%
total_amount['loan_amount'].describe()
# Out:
# count    9.600000e+01
# mean     1.230664e+07
# std      1.821081e+07
# min      5.000000e+03
# 25%      7.139250e+05
# 50%      4.133150e+06
# 75%      1.611655e+07
# max      9.798460e+07
# Name: loan_amount, dtype: float64

# %% [markdown]
# Lo stato con il maggior numero di denaro prestato sono le Filippine, con oltre 97 milioni di dollari, mentre quello con il minor numero è Gaza, con solo 5000 dollari di prestito.

# %%
total_amount.loc[total_amount['loan_amount'].idxmax()]
# Out:
# country_name    Philippines
# loan_amount     9.79846e+07
# Name: 66, dtype: object

# %%
total_amount.loc[total_amount['loan_amount'].idxmin()]
# Out:
# country_name    Gaza
# loan_amount     5000
# Name: 28, dtype: object

# %% [markdown]
# ### 6) Like the previous point, but expressed as a percentage of the overall amount lent

# %%
# punto 6
total_amount['loan_amount'] = total_amount['loan_amount']/total_amount['loan_amount'].sum()*100
total_perc = total_amount.sort_values('loan_amount', ascending=False)
total_perc
# Out:
#       country_name  loan_amount
# 66     Philippines     8.293678
# 65            Peru     6.723825
# 40           Kenya     5.648711
# 64        Paraguay     4.567716
# 14        Cambodia     4.368706
# ..             ...          ...
# 92  Virgin Islands     0.000846
# 90         Vanuatu     0.000783
# 9         Botswana     0.000677
# 89         Uruguay     0.000677
# 28            Gaza     0.000423
#
# [96 rows x 2 columns]

# %% [markdown]
# Per calcolare la percentuale si divide il valore di ogni cella per il totale del prestito moltiplicato per 100.

# %% [markdown]
# ### 7) Like the three previous points, but split for each year (with respect to disburse time).

# %%
# punto 7
loans['disburse_year'] = loans['disburse_time'].dt.year

anno = loans[['country_name','disburse_year','loan_amount']]
anno = anno.dropna()

anno['disburse_year'] = anno['disburse_year'].astype(int)

# %% [markdown]
# Come osservato nel punto 2 la colonna `disburse_year` presenta dei valori mancanti. Le relative righe non possono essere prese in considerazione per svolgere questo esercizio. Viene utilizzata nuovamente la funzione `groupby`.

# %%
total_count = anno.groupby(['country_name','disburse_year']).size()
total_count = pd.DataFrame(total_count)
total_count[0]
# Out:
# country_name  disburse_year
# Afghanistan   2007              408
#               2008              370
#               2009              678
#               2010              632
#               2011              247
#                                ...
# Zimbabwe      2013              426
#               2014             2078
#               2015              600
#               2016              808
#               2017             1079
# Name: 0, Length: 748, dtype: int64

# %%
total_year = anno.groupby(['country_name','disburse_year'])['loan_amount'].sum()
total_year = pd.DataFrame(total_year)
total_year['loan_amount']
# Out:
# country_name  disburse_year
# Afghanistan   2007              194975.0
#               2008              365375.0
#               2009              585125.0
#               2010              563350.0
#               2011              245125.0
#                                  ...
# Zimbabwe      2013              678525.0
#               2014             1311575.0
#               2015              723625.0
#               2016              788600.0
#               2017             1237600.0
# Name: loan_amount, Length: 748, dtype: float64

# %%
total_year['loan_amount'] = total_year['loan_amount']/total_year['loan_amount'].sum()*100
total_year['loan_amount']
# Out:
# country_name  disburse_year
# Afghanistan   2007             0.016657
#               2008             0.031215
#               2009             0.049989
#               2010             0.048129
#               2011             0.020942
#                                  ...
# Zimbabwe      2013             0.057969
#               2014             0.112053
#               2015             0.061822
#               2016             0.067373
#               2017             0.105733
# Name: loan_amount, Length: 748, dtype: float64

# %%
total_year['loan_amount'].sum() # verifica che il totale sia uguale a 100
# Out:
# 100.0

# %% [markdown]
# ### 8) For each lender, compute the overall amount of money lent. For each loan that has more than one lender, you must assume that all lenders contributed the same amount.

# %%
# punto 8
loans_amount = loans[['loan_id','loan_amount','num_lenders_total']]

# %% [markdown]
# Si uniscono il dataset loan_lenders normalizzato e il sottoinsieme di loans, contenente l'id e l'importo del prestito.

# %%
loanlen_amount = pd.merge(loans_amount, loans_lenders, on='loan_id')

# %% [markdown]
# Non conoscendo la quantità di denaro investito di ogni lenders, si divide l'ammontare per il numero di partecipanti al prestito.

# %%
loanlen_amount['amount'] = loanlen_amount['loan_amount']/loanlen_amount.groupby('loan_id').loan_id.transform('count')

# %%
loanlen_amount['amount_2'] = loanlen_amount['loan_amount']/loanlen_amount['num_lenders_total']

# %%
loanlen_amount
# Out:
#           loan_id  loan_amount  num_lenders_total             lenders  \
# 0          657307        125.0                  3         spencer5657
# 1          657307        125.0                  3         matthew8640
# 2          657307        125.0                  3       larry71496105
# 3          657259        400.0                 11                 ltr
# 4          657259        400.0                 11          andrew5306
# ...           ...          ...                ...                 ...
# 28293907   989240        175.0                  7  jensdamsgaardvanar
# 28293908   989240        175.0                  7       david47598776
# 28293909   989240        175.0                  7           bernd9221
# 28293910   989240        175.0                  7     valeria98599473
# 28293911   989240        175.0                  7          donald1853
#
#              amount   amount_2
# 0         41.666667  41.666667
# 1         41.666667  41.666667
# 2         41.666667  41.666667
# 3         57.142857  36.363636
# 4         57.142857  36.363636
# ...             ...        ...
# 28293907  35.000000  25.000000
# 28293908  35.000000  25.000000
# 28293909  35.000000  25.000000
# 28293910  35.000000  25.000000
# 28293911  35.000000  25.000000
#
# [28293912 rows x 6 columns]

# %% [markdown]
# Si raggruppa per lenders e si somma la quantità prestata. Sono riportati due risultati diversi, uno ottenuto dividendo per il numero di lenders in riferimento ai `loan_id` presenti nella tabella `loan_lenders`, l'altro dividendo la quantità totale per il numero di lenders indicato dalla colonna `num_lenders_total`. Per lo svolgimento dei punti successivi, si prenderà in considerazione il primo, in quanto si riferisce direttamente ai lenders effettivamente presenti nel dataset.

# %%
lenders_amount=loanlen_amount[['lenders','amount']].groupby('lenders', as_index=False)['amount'].sum()
lenders_amount=pd.DataFrame(lenders_amount)
lenders_amount
# Out:
#                  lenders       amount
# 0                    000  1672.618411
# 1                  00000  1380.693644
# 2                   0002  2472.563566
# 3               00mike00    52.631579
# 4         0101craign0101  2623.565117
# ...                  ...          ...
# 1639021          zzanita    87.500000
# 1639022       zzcyna7269    55.357143
# 1639023          zzinnia    38.000000
# 1639024         zzmcfate  2287.291955
# 1639025       zzrvmf8538   106.417625
#
# [1639026 rows x 2 columns]

# %%
lenders_amount_2=loanlen_amount[['lenders','amount_2']].groupby('lenders', as_index=False)['amount_2'].sum()
lenders_amount_2=pd.DataFrame(lenders_amount_2)
lenders_amount_2
# Out:
#                  lenders     amount_2
# 0                    000  1485.309656
# 1                  00000  1249.947363
# 2                   0002  2201.180463
# 3               00mike00    38.461538
# 4         0101craign0101  2424.088932
# ...                  ...          ...
# 1639021          zzanita    62.500000
# 1639022       zzcyna7269    44.285714
# 1639023          zzinnia    32.758621
# 1639024         zzmcfate  2033.750197
# 1639025       zzrvmf8538   112.820513
#
# [1639026 rows x 2 columns]

# %% [markdown]
# ### 9) For each country, compute the difference between the overall amount of money lent and the overall amount of money borrowed. Since the country of the lender is often unknown, you can assume that the true distribution among the countries is the same as the one computed from the rows where the country is known.

# %%
#punto 9
lenders
# Out:
#          permanent_name display_name      city     state country_code  \
# 0              qian3013         Qian       NaN       NaN          NaN
# 1             reena6733        Reena       NaN       NaN          NaN
# 2               mai5982          Mai       NaN       NaN          NaN
# 3        andrew86079135       Andrew       NaN       NaN          NaN
# 4            nguyen6962       Nguyen       NaN       NaN          NaN
# ...                 ...          ...       ...       ...          ...
# 2349169       janet7309        Janet       NaN       NaN          NaN
# 2349170          pj4198          NaN       NaN       NaN          NaN
# 2349171       maria2141        Maria       NaN       NaN           US
# 2349172      simone9846       Simone       NaN       NaN          NaN
# 2349173      laurie1160       Laurie  Timonium  Maryland           US
#
#          member_since occupation loan_because  loan_purchase_num invited_by  \
# 0          1461300457        NaN          NaN                1.0        NaN
# 1          1461300634        NaN          NaN                9.0        NaN
# 2          1461300853        NaN          NaN                NaN        NaN
# 3          1461301091        NaN          NaN                5.0  Peter Tan
# 4          1461301154        NaN          NaN                NaN        NaN
# ...               ...        ...          ...                ...        ...
# 2349169    1342097163        NaN          NaN                NaN        NaN
# 2349170    1342097515        NaN          NaN                NaN        NaN
# 2349171    1342099723        NaN          NaN                2.0        NaN
# 2349172    1342100213        NaN          NaN                NaN        NaN
# 2349173    1342101767        NaN          NaN                1.0     Verian
#
#          num_invited
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                  0
# ...              ...
# 2349169            0
# 2349170            0
# 2349171            0
# 2349172            0
# 2349173            0
#
# [2349174 rows x 11 columns]

# %%
lenders.isnull().sum()
# Out:
# permanent_name             0
# display_name            2768
# city                 1619306
# state                1713481
# country_code         1458635
# member_since               0
# occupation           1844514
# loan_because         2174852
# loan_purchase_num     894281
# invited_by           1852349
# num_invited                0
# dtype: int64

# %% [markdown]
# Dato che molti valori di ``country_code`` sono mancanti, assumo che la distribuzione della nazione di provenienza dei lenders sia la medesima di quelli per cui è nota.

# %%
lenders['country_code'].value_counts()
# Out:
# US    591612
# CA     67970
# GB     38380
# AU     37103
# DE     16007
#        ...
# IO         1
# NU         1
# GW         1
# TF         1
# KM         1
# Name: country_code, Length: 234, dtype: int64

# %%
random.seed(123)
x = lenders['country_code'].value_counts(normalize=True)
missing = lenders['country_code'].isnull()
lenders.loc[missing,'country_code'] = np.random.choice(x.index, size=len(lenders[missing]),p=x.values)
lenders
# Out:
#          permanent_name display_name      city     state country_code  \
# 0              qian3013         Qian       NaN       NaN           CA
# 1             reena6733        Reena       NaN       NaN           US
# 2               mai5982          Mai       NaN       NaN           US
# 3        andrew86079135       Andrew       NaN       NaN           US
# 4            nguyen6962       Nguyen       NaN       NaN           ES
# ...                 ...          ...       ...       ...          ...
# 2349169       janet7309        Janet       NaN       NaN           US
# 2349170          pj4198          NaN       NaN       NaN           US
# 2349171       maria2141        Maria       NaN       NaN           US
# 2349172      simone9846       Simone       NaN       NaN           GB
# 2349173      laurie1160       Laurie  Timonium  Maryland           US
#
#          member_since occupation loan_because  loan_purchase_num invited_by  \
# 0          1461300457        NaN          NaN                1.0        NaN
# 1          1461300634        NaN          NaN                9.0        NaN
# 2          1461300853        NaN          NaN                NaN        NaN
# 3          1461301091        NaN          NaN                5.0  Peter Tan
# 4          1461301154        NaN          NaN                NaN        NaN
# ...               ...        ...          ...                ...        ...
# 2349169    1342097163        NaN          NaN                NaN        NaN
# 2349170    1342097515        NaN          NaN                NaN        NaN
# 2349171    1342099723        NaN          NaN                2.0        NaN
# 2349172    1342100213        NaN          NaN                NaN        NaN
# 2349173    1342101767        NaN          NaN                1.0     Verian
#
#          num_invited
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                  0
# ...              ...
# 2349169            0
# 2349170            0
# 2349171            0
# 2349172            0
# 2349173            0
#
# [2349174 rows x 11 columns]

# %% [markdown]
# Isolo il nome e la relativa nazione di appartenenza (espressa con il codice).

# %%
lenders_country = lenders[['permanent_name','country_code']]

# %%
lenders_country
# Out:
#          permanent_name country_code
# 0              qian3013           CA
# 1             reena6733           US
# 2               mai5982           US
# 3        andrew86079135           US
# 4            nguyen6962           ES
# ...                 ...          ...
# 2349169       janet7309           US
# 2349170          pj4198           US
# 2349171       maria2141           US
# 2349172      simone9846           GB
# 2349173      laurie1160           US
#
# [2349174 rows x 2 columns]

# %%
utf = lenders_amount.lenders.str.encode('utf-8')
utf
# Out:
# 0                     b' 000'
# 1                   b' 00000'
# 2                    b' 0002'
# 3                b' 00mike00'
# 4          b' 0101craign0101'
#                   ...
# 1639021            b'zzanita'
# 1639022         b'zzcyna7269'
# 1639023            b'zzinnia'
# 1639024           b'zzmcfate'
# 1639025         b'zzrvmf8538'
# Name: lenders, Length: 1639026, dtype: object

# %% [markdown]
# Prima di poter unire le tabelle `lenders_country` e `lenders_amount` è necessario applicare la funzione `str.strip`: aluni nomi dei lenders del dataset sono rappresentati con spazi bianchi all'inizio della stringa. Ciò altererebbe il risultato del join, che andrà fatto proprio su quella colonna.

# %%
lenders_amount.lenders = lenders_amount.lenders.str.strip()

# %%
len_country_amount = pd.merge(lenders_country, lenders_amount, left_on='permanent_name', right_on='lenders')
len_country_amount.drop('lenders', axis=1, inplace=True)

# %%
len_country_amount
# Out:
#          permanent_name country_code      amount
# 0              qian3013           CA   46.839080
# 1             reena6733           US  417.948366
# 2        andrew86079135           US  349.601088
# 3          sirinapa6764           US   50.000000
# 4              rene7585           US   59.126984
# ...                 ...          ...         ...
# 1639021       carol8279           US  169.440389
# 1639022    eric91401545           US   63.780488
# 1639023    kate40761039           SE   36.280488
# 1639024       maria2141           US  110.507246
# 1639025      laurie1160           US   36.280488
#
# [1639026 rows x 3 columns]

# %%
len_country_amount.isnull().sum()
# Out:
# permanent_name    0
# country_code      0
# amount            0
# dtype: int64

# %% [markdown]
# Raggruppando per codice nazione, è possibile calcolare l'ammontare prestato da ogni stato.

# %%
country_lent = len_country_amount.groupby('country_code', as_index=False)['amount'].sum()

# %%
country_lent
# Out:
#     country_code        amount
# 0             AD  7.298314e+03
# 1             AE  1.980805e+06
# 2             AF  1.625091e+05
# 3             AG  1.017774e+03
# 4             AI  6.947933e+02
# ..           ...           ...
# 225           YE  7.108932e+04
# 226           YT  4.603746e+02
# 227           ZA  7.486100e+05
# 228           ZM  4.657092e+04
# 229           ZW  1.154654e+04
#
# [230 rows x 2 columns]

# %% [markdown]
# Come nel punto 5, ma utilizzando il codice nazione. Vi è una riga in meno rispetto all'esercizio citato precedentemente, dato che il codice dello stato Namibia è mancante (come si vedrà successivamente osservando il file `country_stats`).

# %%
country_borrowed = loans.groupby(['country_code'], as_index=False)['loan_amount'].sum()
country_borrowed
# Out:
#    country_code  loan_amount
# 0            AF    1967950.0
# 1            AL    4307350.0
# 2            AM   22950475.0
# 3            AZ   14784625.0
# 4            BA     477250.0
# ..          ...          ...
# 90           XK    3083025.0
# 91           YE    3444000.0
# 92           ZA    1006525.0
# 93           ZM    1978975.0
# 94           ZW    5851875.0
#
# [95 rows x 2 columns]

# %% [markdown]
# Si uniscono i due dataset. I valori mancanti sono imputati come degli 0, considerando che in mancanza di informazione uno stato non abbia ricevuto/effettuato prestiti.

# %%
quantità = pd.merge(country_lent, country_borrowed, how='outer', on = 'country_code')
quantità.columns = ['country_code', 'money_lent','money_borrowed']
quantità.fillna(0, inplace=True)

# %%
quantità
# Out:
#     country_code    money_lent  money_borrowed
# 0             AD  7.298314e+03             0.0
# 1             AE  1.980805e+06             0.0
# 2             AF  1.625091e+05       1967950.0
# 3             AG  1.017774e+03             0.0
# 4             AI  6.947933e+02             0.0
# ..           ...           ...             ...
# 226           YT  4.603746e+02             0.0
# 227           ZA  7.486100e+05       1006525.0
# 228           ZM  4.657092e+04       1978975.0
# 229           ZW  1.154654e+04       5851875.0
# 230           TD  0.000000e+00         20075.0
#
# [231 rows x 3 columns]

# %%
quantità['difference'] = quantità['money_lent'] - quantità['money_borrowed']

# %%
quantità.sort_values('difference', ascending=False)
# Out:
#     country_code    money_lent  money_borrowed    difference
# 212           US  7.171820e+08      46352000.0  6.708300e+08
# 35            CA  9.660530e+07         50000.0  9.655530e+07
# 13            AU  6.130693e+07             0.0  6.130693e+07
# 72            GB  5.695232e+07             0.0  5.695232e+07
# 52            DE  3.600546e+07             0.0  3.600546e+07
# ..           ...           ...             ...           ...
# 107           KH  1.293341e+05      51613525.0 -5.148419e+07
# 169           PY  5.880376e+04      53964700.0 -5.390590e+07
# 105           KE  1.007956e+06      66735975.0 -6.572802e+07
# 158           PE  1.702506e+05      79437775.0 -7.926752e+07
# 161           PH  1.293779e+06      97984600.0 -9.669082e+07
#
# [231 rows x 4 columns]

# %% [markdown]
# Lo stato con la differenza più elevata tra denaro prestato e ricevuto sono gli USA, mentre quello con la più bassa le Filippine.

# %% [markdown]
# ### 10) Which country has the highest ratio between the difference computed at the previous point and the population?
#
# ### 11) Which country has the highest ratio between the difference computed at point 9 and the population that is not below the poverty line?

# %%
#punto 10 e 11 
country_stats = pd.read_csv("country_stats.csv")

# %%
country_stats
# Out:
#                  country_name country_code country_code3 continent  \
# 0                       India           IN           IND      Asia
# 1                     Nigeria           NG           NGA    Africa
# 2                      Mexico           MX           MEX  Americas
# 3                    Pakistan           PK           PAK      Asia
# 4                  Bangladesh           BD           BGD      Asia
# ..                        ...          ...           ...       ...
# 169                   Somalia           SO           SOM    Africa
# 170  Central African Republic           CF           CAF    Africa
# 171                     Samoa           WS           WSM   Oceania
# 172                 Palestine           PS            PS      Asia
# 173                    Kosovo           XK           NaN    Europe
#
#               region  population  population_below_poverty_line       hdi  \
# 0      Southern Asia  1339180127                           21.9  0.623559
# 1     Western Africa   190886311                           70.0  0.527105
# 2    Central America   129163276                           46.2  0.761683
# 3      Southern Asia   197015955                           29.5  0.550354
# 4      Southern Asia   164669751                           31.5  0.578824
# ..               ...         ...                            ...       ...
# 169   Eastern Africa    14742523                            NaN       NaN
# 170    Middle Africa     4659080                            NaN  0.352440
# 171        Polynesia      196440                            NaN  0.702000
# 172     Western Asia     4920724                            NaN  0.677000
# 173  Southern Europe     1895250                           30.0  0.786000
#
#      life_expectancy  expected_years_of_schooling  mean_years_of_schooling  \
# 0             68.322                    11.696590                 6.298834
# 1             53.057                     9.970482                 6.000000
# 2             76.972                    13.299090                 8.554985
# 3             66.365                     8.106910                 5.089460
# 4             71.985                    10.178706                 5.241577
# ..               ...                          ...                      ...
# 169              NaN                          NaN                      NaN
# 170           51.458                     7.098980                 4.230000
# 171              NaN                          NaN                      NaN
# 172              NaN                          NaN                      NaN
# 173              NaN                          NaN                      NaN
#
#               gni         kiva_country_name
# 0     5663.474799                     India
# 1     5442.901264                   Nigeria
# 2    16383.106680                    Mexico
# 3     5031.173074                  Pakistan
# 4     3341.490722                Bangladesh
# ..            ...                       ...
# 169           NaN                   Somalia
# 170    587.473961  Central African Republic
# 171           NaN                     Samoa
# 172           NaN                 Palestine
# 173           NaN                    Kosovo
#
# [174 rows x 13 columns]

# %%
country_stats.isnull().sum()
# Out:
# country_name                      0
# country_code                      1
# country_code3                     1
# continent                         0
# region                            0
# population                        0
# population_below_poverty_line    22
# hdi                               3
# life_expectancy                   6
# expected_years_of_schooling       6
# mean_years_of_schooling           6
# gni                               6
# kiva_country_name                 0
# dtype: int64

# %%
country_stats[country_stats.isna().any(axis=1)] # la Namibia è l'unico stato con il codice mancante
# Out:
#                  country_name country_code country_code3 continent  \
# 115                   Namibia          NaN           NAM    Africa
# 151                 Australia           AU           AUS   Oceania
# 152                   Bahrain           BH           BHR      Asia
# 153                    Brunei           BN           BRN      Asia
# 154                      Cuba           CU           CUB  Americas
# 155                    Cyprus           CY           CYP      Asia
# 156                   Finland           FI           FIN    Europe
# 157                   Iceland           IS           ISL    Europe
# 158                    Kuwait           KW           KWT      Asia
# 159                Luxembourg           LU           LUX    Europe
# 160               New Zealand           NZ           NZL   Oceania
# 161               North Korea           KP           PRK      Asia
# 162                    Norway           NO           NOR    Europe
# 163                      Oman           OM           OMN      Asia
# 164               Puerto Rico           PR           PRI  Americas
# 165                     Qatar           QA           QAT      Asia
# 166              Saudi Arabia           SA           SAU      Asia
# 167                 Singapore           SG           SGP      Asia
# 168           Solomon Islands           SB           SLB   Oceania
# 169                   Somalia           SO           SOM    Africa
# 170  Central African Republic           CF           CAF    Africa
# 171                     Samoa           WS           WSM   Oceania
# 172                 Palestine           PS            PS      Asia
# 173                    Kosovo           XK           NaN    Europe
#
#                         region  population  population_below_poverty_line  \
# 115            Southern Africa     2533794                           28.7
# 151  Australia and New Zealand    24450561                            NaN
# 152               Western Asia     1492584                            NaN
# 153         South-eastern Asia      428697                            NaN
# 154                  Caribbean    11484636                            NaN
# 155               Western Asia     1179551                            NaN
# 156            Northern Europe     5523231                            NaN
# 157            Northern Europe      335025                            NaN
# 158               Western Asia     4136528                            NaN
# 159             Western Europe      583455                            NaN
# 160  Australia and New Zealand     4705818                            NaN
# 161               Eastern Asia    25490965                            NaN
# 162            Northern Europe     5305383                            NaN
# 163               Western Asia     4636262                            NaN
# 164                  Caribbean     3663131                            NaN
# 165               Western Asia     2639211                            NaN
# 166               Western Asia    32938213                            NaN
# 167         South-eastern Asia     5708844                            NaN
# 168                  Melanesia      611343                            NaN
# 169             Eastern Africa    14742523                            NaN
# 170              Middle Africa     4659080                            NaN
# 171                  Polynesia      196440                            NaN
# 172               Western Asia     4920724                            NaN
# 173            Southern Europe     1895250                           30.0
#
#           hdi  life_expectancy  expected_years_of_schooling  \
# 115  0.640007           65.062                    11.657589
# 151  0.938680           82.537                    20.432720
# 152  0.823884           76.715                    14.500000
# 153  0.864937           79.019                    14.944860
# 154  0.774669           79.573                    13.937390
# 155  0.855646           80.332                    14.256130
# 156  0.894517           81.006                    17.047920
# 157  0.921110           82.724                    18.994220
# 158  0.800183           74.549                    13.260000
# 159  0.898465           81.881                    13.863730
# 160  0.914900           82.026                    19.228200
# 161       NaN              NaN                          NaN
# 162  0.949423           81.711                    17.671870
# 163  0.795779           76.970                    13.740850
# 164       NaN              NaN                          NaN
# 165  0.855531           78.323                    13.406100
# 166  0.846602           74.444                    16.112270
# 167  0.924866           83.209                    15.400000
# 168  0.514999           68.107                     9.610000
# 169       NaN              NaN                          NaN
# 170  0.352440           51.458                     7.098980
# 171  0.702000              NaN                          NaN
# 172  0.677000              NaN                          NaN
# 173  0.786000              NaN                          NaN
#
#      mean_years_of_schooling            gni         kiva_country_name
# 115                 6.676000    9769.848507                   Namibia
# 151                13.175100   42822.196270                 Australia
# 152                 9.419000   37236.363040                   Bahrain
# 153                 9.020000   72843.466090                    Brunei
# 154                11.750781    7455.062477                      Cuba
# 155                11.695230   29458.522690                    Cyprus
# 156                11.194000   38868.135520                   Finland
# 157                12.190892   37065.214510                   Iceland
# 158                 7.265369   76075.207350                    Kuwait
# 159                11.950833   62470.591290                Luxembourg
# 160                12.503000   32870.078360               New Zealand
# 161                      NaN            NaN               North Korea
# 162                12.746420   67614.353480                    Norway
# 163                 8.100000   34402.275500                      Oman
# 164                      NaN            NaN               Puerto Rico
# 165                 9.764630  129915.600900                     Qatar
# 166                 9.627520   51320.113230              Saudi Arabia
# 167                11.572410   78162.323870                 Singapore
# 168                 5.330584    1560.858813           Solomon Islands
# 169                      NaN            NaN                   Somalia
# 170                 4.230000     587.473961  Central African Republic
# 171                      NaN            NaN                     Samoa
# 172                      NaN            NaN                 Palestine
# 173                      NaN            NaN                    Kosovo

# %% [markdown]
# Calcolo la popolazione sopra la soglia di povertà.

# %%
country_stats['not_poors'] = (country_stats['population']/100) * (100-country_stats['population_below_poverty_line'])

# %%
country_stats
# Out:
#                  country_name country_code country_code3 continent  \
# 0                       India           IN           IND      Asia
# 1                     Nigeria           NG           NGA    Africa
# 2                      Mexico           MX           MEX  Americas
# 3                    Pakistan           PK           PAK      Asia
# 4                  Bangladesh           BD           BGD      Asia
# ..                        ...          ...           ...       ...
# 169                   Somalia           SO           SOM    Africa
# 170  Central African Republic           CF           CAF    Africa
# 171                     Samoa           WS           WSM   Oceania
# 172                 Palestine           PS            PS      Asia
# 173                    Kosovo           XK           NaN    Europe
#
#               region  population  population_below_poverty_line       hdi  \
# 0      Southern Asia  1339180127                           21.9  0.623559
# 1     Western Africa   190886311                           70.0  0.527105
# 2    Central America   129163276                           46.2  0.761683
# 3      Southern Asia   197015955                           29.5  0.550354
# 4      Southern Asia   164669751                           31.5  0.578824
# ..               ...         ...                            ...       ...
# 169   Eastern Africa    14742523                            NaN       NaN
# 170    Middle Africa     4659080                            NaN  0.352440
# 171        Polynesia      196440                            NaN  0.702000
# 172     Western Asia     4920724                            NaN  0.677000
# 173  Southern Europe     1895250                           30.0  0.786000
#
#      life_expectancy  expected_years_of_schooling  mean_years_of_schooling  \
# 0             68.322                    11.696590                 6.298834
# 1             53.057                     9.970482                 6.000000
# 2             76.972                    13.299090                 8.554985
# 3             66.365                     8.106910                 5.089460
# 4             71.985                    10.178706                 5.241577
# ..               ...                          ...                      ...
# 169              NaN                          NaN                      NaN
# 170           51.458                     7.098980                 4.230000
# 171              NaN                          NaN                      NaN
# 172              NaN                          NaN                      NaN
# 173              NaN                          NaN                      NaN
#
#               gni         kiva_country_name     not_poors
# 0     5663.474799                     India  1.045900e+09
# 1     5442.901264                   Nigeria  5.726589e+07
# 2    16383.106680                    Mexico  6.948984e+07
# 3     5031.173074                  Pakistan  1.388962e+08
# 4     3341.490722                Bangladesh  1.127988e+08
# ..            ...                       ...           ...
# 169           NaN                   Somalia           NaN
# 170    587.473961  Central African Republic           NaN
# 171           NaN                     Samoa           NaN
# 172           NaN                 Palestine           NaN
# 173           NaN                    Kosovo  1.326675e+06
#
# [174 rows x 14 columns]

# %% [markdown]
# Si uniscono la tabella risultata dal punto precedente con quella contenente le informazioni sugli stati e la relativa popolazione.

# %%
country = pd.merge(quantità, country_stats, on='country_code')

# %% [markdown]
# Vengono quindi calcolati i due rapporti richiesti.

# %%
country['ratio_population'] = country['difference']/country['population']
country['ratio_not_poors'] = country['difference']/country['not_poors']

# %%
country.loc[country['ratio_population'].idxmax()]
# Out:
# country_code                                  NO
# money_lent                             2.066e+07
# money_borrowed                                 0
# difference                             2.066e+07
# country_name                              Norway
# country_code3                                NOR
# continent                                 Europe
# region                           Northern Europe
# population                               5305383
# population_below_poverty_line                NaN
# hdi                                     0.949423
# life_expectancy                           81.711
# expected_years_of_schooling              17.6719
# mean_years_of_schooling                  12.7464
# gni                                      67614.4
# kiva_country_name                         Norway
# not_poors                                    NaN
# ratio_population                         3.89416
# ratio_not_poors                              NaN
# Name: 113, dtype: object

# %%
country.loc[country['ratio_not_poors'].idxmax()]
# Out:
# country_code                                   CA
# money_lent                            9.66053e+07
# money_borrowed                              50000
# difference                            9.65553e+07
# country_name                               Canada
# country_code3                                 CAN
# continent                                Americas
# region                           Northern America
# population                               36624199
# population_below_poverty_line                 9.4
# hdi                                      0.920284
# life_expectancy                            82.224
# expected_years_of_schooling                16.325
# mean_years_of_schooling                   13.1051
# gni                                       42581.9
# kiva_country_name                          Canada
# not_poors                             3.31815e+07
# ratio_population                          2.63638
# ratio_not_poors                           2.90991
# Name: 24, dtype: object

# %% [markdown]
# Attraverso la funzione `idxmax` trovo gli stati con il rapporto maggiore. Al primo posto la Norvegia per la popolazione totale (risultato influenzato dal fatto che non sono registrati prestiti in entrata), mentre riguardo la popolazione sopra la soglia di povertà il Canada (per Norvegia il dato era mancante).

# %%
country.sort_values('ratio_population', ascending=False)
# Out:
#     country_code    money_lent  money_borrowed    difference   country_name  \
# 113           NO  2.065999e+07             0.0  2.065999e+07         Norway
# 24            CA  9.660530e+07         50000.0  9.655530e+07         Canada
# 7             AU  6.130693e+07             0.0  6.130693e+07      Australia
# 71            IS  7.265353e+05             0.0  7.265353e+05        Iceland
# 158           US  7.171820e+08      46352000.0  6.708300e+08  United States
# ..           ...           ...             ...           ...            ...
# 100           MN  7.666151e+04      15348375.0 -1.527171e+07       Mongolia
# 144           SV  6.269675e+04      41691550.0 -4.162885e+07    El Salvador
# 3             AM  6.809825e+04      22950475.0 -2.288238e+07        Armenia
# 126           PY  5.880376e+04      53964700.0 -5.390590e+07       Paraguay
# 163           WS  1.647056e+03      12212175.0 -1.221053e+07          Samoa
#
#     country_code3 continent                     region  population  \
# 113           NOR    Europe            Northern Europe     5305383
# 24            CAN  Americas           Northern America    36624199
# 7             AUS   Oceania  Australia and New Zealand    24450561
# 71            ISL    Europe            Northern Europe      335025
# 158           USA  Americas           Northern America   324459463
# ..            ...       ...                        ...         ...
# 100           MNG      Asia               Eastern Asia     3075647
# 144           SLV  Americas            Central America     6377853
# 3             ARM      Asia               Western Asia     2930450
# 126           PRY  Americas              South America     6811297
# 163           WSM   Oceania                  Polynesia      196440
#
#      population_below_poverty_line       hdi  life_expectancy  \
# 113                            NaN  0.949423           81.711
# 24                             9.4  0.920284           82.224
# 7                              NaN  0.938680           82.537
# 71                             NaN  0.921110           82.724
# 158                           15.1  0.919553           79.222
# ..                             ...       ...              ...
# 100                           21.6  0.734832           69.806
# 144                           34.9  0.679777           73.271
# 3                             32.0  0.742850           74.886
# 126                           22.2  0.692966           73.004
# 163                            NaN  0.702000              NaN
#
#      expected_years_of_schooling  mean_years_of_schooling           gni  \
# 113                    17.671870                12.746420  67614.353480
# 24                     16.325000                13.105115  42581.914330
# 7                      20.432720                13.175100  42822.196270
# 71                     18.994220                12.190892  37065.214510
# 158                    16.538150                13.217890  53245.076960
# ..                           ...                      ...           ...
# 100                    14.845520                 9.750000  10449.207270
# 144                    13.169930                 6.532388   7732.025398
# 3                      12.713218                11.291050   8189.115193
# 126                    12.318430                 8.135100   8181.693782
# 163                          NaN                      NaN           NaN
#
#     kiva_country_name     not_poors  ratio_population  ratio_not_poors
# 113            Norway           NaN          3.894156              NaN
# 24             Canada  3.318152e+07          2.636380         2.909912
# 7           Australia           NaN          2.507383              NaN
# 71            Iceland           NaN          2.168600              NaN
# 158     United States  2.754661e+08          2.067531         2.435254
# ..                ...           ...               ...              ...
# 100          Mongolia  2.411307e+06         -4.965366        -6.333375
# 144       El Salvador  4.151982e+06         -6.527095       -10.026260
# 3             Armenia  1.992706e+06         -7.808486       -11.483067
# 126          Paraguay  5.299189e+06         -7.914190       -10.172480
# 163             Samoa           NaN        -62.159071              NaN
#
# [170 rows x 19 columns]

# %%
country.sort_values('ratio_not_poors', ascending=False)
# Out:
#     country_code    money_lent  money_borrowed    difference     country_name  \
# 24            CA  9.660530e+07         50000.0  9.655530e+07           Canada
# 158           US  7.171820e+08      46352000.0  6.708300e+08    United States
# 135           SE  1.626307e+07             0.0  1.626307e+07           Sweden
# 112           NL  2.711827e+07             0.0  2.711827e+07      Netherlands
# 27            CH  1.120694e+07             0.0  1.120694e+07      Switzerland
# ..           ...           ...             ...           ...              ...
# 132           SA  1.045613e+06             0.0  1.045613e+06     Saudi Arabia
# 133           SB  3.324230e+03        815575.0 -8.122508e+05  Solomon Islands
# 136           SG  3.502015e+06             0.0  3.502015e+06        Singapore
# 141           SO  5.455206e+03        308725.0 -3.032698e+05          Somalia
# 163           WS  1.647056e+03      12212175.0 -1.221053e+07            Samoa
#
#     country_code3 continent              region  population  \
# 24            CAN  Americas    Northern America    36624199
# 158           USA  Americas    Northern America   324459463
# 135           SWE    Europe     Northern Europe     9910701
# 112           NLD    Europe      Western Europe    17035938
# 27            CHE    Europe      Western Europe     8476005
# ..            ...       ...                 ...         ...
# 132           SAU      Asia        Western Asia    32938213
# 133           SLB   Oceania           Melanesia      611343
# 136           SGP      Asia  South-eastern Asia     5708844
# 141           SOM    Africa      Eastern Africa    14742523
# 163           WSM   Oceania           Polynesia      196440
#
#      population_below_poverty_line       hdi  life_expectancy  \
# 24                             9.4  0.920284           82.224
# 158                           15.1  0.919553           79.222
# 135                           15.0  0.912706           82.347
# 112                            8.8  0.924312           81.706
# 27                             6.6  0.939131           83.133
# ..                             ...       ...              ...
# 132                            NaN  0.846602           74.444
# 133                            NaN  0.514999           68.107
# 136                            NaN  0.924866           83.209
# 141                            NaN       NaN              NaN
# 163                            NaN  0.702000              NaN
#
#      expected_years_of_schooling  mean_years_of_schooling           gni  \
# 24                     16.325000                13.105115  42581.914330
# 158                    16.538150                13.217890  53245.076960
# 135                    16.055459                12.273700  46250.793820
# 112                    18.116540                11.914070  46325.576580
# 27                     16.040410                13.370000  56363.957800
# ..                           ...                      ...           ...
# 132                    16.112270                 9.627520  51320.113230
# 133                     9.610000                 5.330584   1560.858813
# 136                    15.400000                11.572410  78162.323870
# 141                          NaN                      NaN           NaN
# 163                          NaN                      NaN           NaN
#
#     kiva_country_name     not_poors  ratio_population  ratio_not_poors
# 24             Canada  3.318152e+07          2.636380         2.909912
# 158     United States  2.754661e+08          2.067531         2.435254
# 135            Sweden  8.424096e+06          1.640961         1.930542
# 112       Netherlands  1.553678e+07          1.591827         1.745425
# 27        Switzerland  7.916589e+06          1.322196         1.415627
# ..                ...           ...               ...              ...
# 132      Saudi Arabia           NaN          0.031745              NaN
# 133   Solomon Islands           NaN         -1.328633              NaN
# 136         Singapore           NaN          0.613437              NaN
# 141           Somalia           NaN         -0.020571              NaN
# 163             Samoa           NaN        -62.159071              NaN
#
# [170 rows x 19 columns]

# %% [markdown]
# ### 12) For each year, compute the total amount of loans. Each loan that has planned expiration time and disburse time in different years must have its amount distributed proportionally to the number of days in each year. For example, a loan with disburse time December 1st, 2016, planned expiration time January 30th 2018, and amount 5000USD has an amount of 5000USD * 31 / (31+365+30) = 363.85 for 2016, 5000USD * 365 / (31+365+30) = 4284.04 for 2017, and 5000USD * 30 / (31+365+30) = 352.11 for 2018.

# %%
#punto 12
loans
# Out:
#          loan_id           loan_name original_language  \
# 0         657307                Aivy           English
# 1         657259      Idalia Marizza           Spanish
# 2         658010               Aasia           English
# 3         659347             Gulmira           Russian
# 4         656933             Ricky\t           English
# ...          ...                 ...               ...
# 1419602   988180                 NaN               NaN
# 1419603   988213             Perlita           English
# 1419604   989109  Okyeso Nyame Group           English
# 1419605   989143            Exequila           English
# 1419606   989240               Lydia            French
#
#                                                description  \
# 0        Aivy, 21 years of age, is single and lives in ...
# 1        Doña Idalia, esta casada, tiene 57 años de eda...
# 2        Aasia is a 45-year-old married lady and she ha...
# 3        Гулмире 36 лет, замужем, вместе с супругом вос...
# 4        Ricky is a farmer who currently cultivates his...
# ...                                                    ...
# 1419602                                                NaN
# 1419603  Perlita is 52 years old, married and has three...
# 1419604  Okyeso Nyame group will begin its third cycle ...
# 1419605  Exequila  is from San Miguel, Bohol. She is in...
# 1419606  Lydia a 37ans et habite dans une zone rurale. ...
#
#                                     description_translated  funded_amount  \
# 0                                                      NaN          125.0
# 1        Idalia, 57, is married and lives with her husb...          400.0
# 2                                                      NaN          400.0
# 3        Gulmira is 36 years old and married.  She and ...          625.0
# 4                                                      NaN          425.0
# ...                                                    ...            ...
# 1419602                                                NaN          400.0
# 1419603  Perlita is 52 years old, married and has three...          300.0
# 1419604  Okyeso Nyame group will begin its third cycle ...         2425.0
# 1419605  Exequila  is from San Miguel, Bohol. She is in...          100.0
# 1419606  Lydia is 37 years old and lives in a rural are...          175.0
#
#          loan_amount  status  activity_name  sector_name  \
# 0              125.0  funded  General Store       Retail
# 1              400.0  funded  Used Clothing     Clothing
# 2              400.0  funded  General Store       Retail
# 3              625.0  funded        Farming  Agriculture
# 4              425.0  funded        Farming  Agriculture
# ...              ...     ...            ...          ...
# 1419602        400.0  funded      Tailoring     Services
# 1419603        300.0  funded           Pigs  Agriculture
# 1419604       2425.0  funded         Bakery         Food
# 1419605        100.0  funded        Farming  Agriculture
# 1419606        175.0  funded         Sewing     Services
#
#                                                   loan_use country_code  \
# 0         to buy additional inventories for her sari-sa...           PH
# 1        To buy American clothing such as blouses, shir...           HN
# 2                    to buy stock of rice, sugar and flour           PK
# 3        to buy cucumber and tomato seeds, as well as f...           KG
# 4         to buy organic fertilizer and agrochemical pr...           PH
# ...                                                    ...          ...
# 1419602                                                NaN           KE
# 1419603  to buy feeds and other supplies to raise her pigs           PH
# 1419604  to buy margarine, flour and sugar at wholesale...           GH
# 1419605                            to buy feed and piglets           PH
# 1419606  to buy a sewing machine, a sewing machine moto...           MG
#
#         country_name                       town_name currency_policy  \
# 0        Philippines            Ozamiz - Ozamiz City          shared
# 1           Honduras               La Lopez, Choloma          shared
# 2           Pakistan                       Lala Musa          shared
# 3         Kyrgyzstan      Aravan village, Osh region          shared
# 4        Philippines  Baleleng, Sto. Thomas, Isabela          shared
# ...              ...                             ...             ...
# 1419602        Kenya                             NaN          shared
# 1419603  Philippines                 Numancia, Aklan          shared
# 1419604        Ghana                         Chorkor          shared
# 1419605  Philippines               San Miguel, Bohol          shared
# 1419606   Madagascar                    Antananarivo          shared
#
#          currency_exchange_coverage_rate currency  partner_id  \
# 0                                    0.1      PHP       126.0
# 1                                    0.1      HNL       201.0
# 2                                    0.1      PKR       245.0
# 3                                    0.1      KGS       171.0
# 4                                    0.1      PHP       123.0
# ...                                  ...      ...         ...
# 1419602                              0.1      KES       138.0
# 1419603                              0.1      PHP       145.0
# 1419604                              0.1      GHS       231.0
# 1419605                              0.1      PHP       125.0
# 1419606                              0.1      MGA       443.0
#
#                            posted_time   planned_expiration_time  \
# 0        2014-01-15 02:23:45.000 +0000 2014-02-14 03:30:06+00:00
# 1        2014-01-14 20:23:20.000 +0000 2014-03-26 22:25:07+00:00
# 2        2014-01-16 11:32:58.000 +0000 2014-02-15 21:10:05+00:00
# 3        2014-01-20 09:59:48.000 +0000 2014-02-21 03:10:02+00:00
# 4        2014-01-14 05:46:21.000 +0000 2014-02-13 06:10:02+00:00
# ...                                ...                       ...
# 1419602  2015-12-01 04:49:50.000 +0000 2016-01-02 01:00:03+00:00
# 1419603  2015-12-01 05:13:30.000 +0000 2016-01-02 16:40:07+00:00
# 1419604  2015-12-02 10:56:28.000 +0000 2016-01-03 22:20:04+00:00
# 1419605  2015-12-02 11:41:46.000 +0000 2016-01-05 08:50:02+00:00
# 1419606  2015-12-02 13:55:07.000 +0000 2016-01-03 20:50:06+00:00
#
#                     disburse_time                    raised_time  lender_term  \
# 0       2013-12-22 08:00:00+00:00  2014-01-15 04:48:22.000 +0000          7.0
# 1       2013-12-20 08:00:00+00:00  2014-02-25 06:42:06.000 +0000          8.0
# 2       2014-01-09 08:00:00+00:00  2014-01-24 23:06:18.000 +0000         14.0
# 3       2014-01-17 08:00:00+00:00  2014-01-22 05:29:28.000 +0000         14.0
# 4       2013-12-17 08:00:00+00:00  2014-01-14 17:29:27.000 +0000          7.0
# ...                           ...                            ...          ...
# 1419602 2015-11-23 08:00:00+00:00  2015-12-28 15:44:18.000 +0000         14.0
# 1419603 2015-11-24 08:00:00+00:00  2015-12-22 10:37:06.000 +0000         14.0
# 1419604 2015-11-13 08:00:00+00:00  2015-12-26 20:24:47.000 +0000          8.0
# 1419605 2015-11-03 08:00:00+00:00  2015-12-06 21:03:57.000 +0000         12.0
# 1419606 2015-11-03 08:00:00+00:00  2015-12-04 23:17:04.000 +0000         14.0
#
#          num_lenders_total  num_journal_entries  num_bulk_entries  \
# 0                        3                    2                 1
# 1                       11                    2                 1
# 2                       16                    2                 1
# 3                       21                    2                 1
# 4                       15                    2                 1
# ...                    ...                  ...               ...
# 1419602                 16                    4                 2
# 1419603                 12                    1                 1
# 1419604                 76                    2                 1
# 1419605                  3                    1                 1
# 1419606                  7                    1                 1
#
#                                                       tags  \
# 0                                                      NaN
# 1                                                      NaN
# 2        #Woman Owned Biz, #Supporting Family, user_fav...
# 3                                            user_favorite
# 4                 #Animals, #Eco-friendly, #Sustainable Ag
# ...                                                    ...
# 1419602        #Parent, #Repeat Borrower, #Woman Owned Biz
# 1419603  #Animals, #Elderly, #Repeat Borrower, #Woman O...
# 1419604  user_favorite, #Parent, #Vegan, #Woman Owned B...
# 1419605                                                NaN
# 1419606                                                NaN
#
#                                    borrower_genders  \
# 0                                            female
# 1                                            female
# 2                                            female
# 3                                            female
# 4                                              male
# ...                                             ...
# 1419602                                         NaN
# 1419603                                      female
# 1419604  female, female, female, male, male, female
# 1419605                                      female
# 1419606                                      female
#
#                           borrower_pictured repayment_interval  \
# 0                                      true          irregular
# 1                                      true            monthly
# 2                                      true            monthly
# 3                                      true            monthly
# 4                                      true             bullet
# ...                                     ...                ...
# 1419602                                 NaN            monthly
# 1419603                                true          irregular
# 1419604  true, true, true, true, true, true          irregular
# 1419605                                true          irregular
# 1419606                                true            monthly
#
#         distribution_model disburse_date planned_expiration_date duration  \
# 0            field_partner    2013-12-22              2014-02-14  54 days
# 1            field_partner    2013-12-20              2014-03-26  96 days
# 2            field_partner    2014-01-09              2014-02-15  37 days
# 3            field_partner    2014-01-17              2014-02-21  35 days
# 4            field_partner    2013-12-17              2014-02-13  58 days
# ...                    ...           ...                     ...      ...
# 1419602      field_partner    2015-11-23              2016-01-02  40 days
# 1419603      field_partner    2015-11-24              2016-01-02  39 days
# 1419604      field_partner    2015-11-13              2016-01-03  51 days
# 1419605      field_partner    2015-11-03              2016-01-05  63 days
# 1419606      field_partner    2015-11-03              2016-01-03  61 days
#
#          disburse_year
# 0               2013.0
# 1               2013.0
# 2               2014.0
# 3               2014.0
# 4               2013.0
# ...                ...
# 1419602         2015.0
# 1419603         2015.0
# 1419604         2015.0
# 1419605         2015.0
# 1419606         2015.0
#
# [1419607 rows x 35 columns]

# %% [markdown]
# Estraggo gli anni in cui sono stati effettuati i prestiti, dopodichè identifico quelli bisestili (nel range presente nel database sono 2008, 2012 e 2016).

# %%
loans['disburse_time'].dt.year.unique()
# Out:
# array([2013., 2014., 2015., 2012., 2016., 2010., 2017., 2018., 2009.,
#        2011., 2007.,   nan, 2006., 2008., 2005.])

# %%
loans['planned_expiration_time'].dt.year.unique()
# Out:
# array([2014., 2015., 2012., 2016.,   nan, 2017., 2013., 2018.])

# %%
bisestili = {2008, 2012, 2016}

# %% [markdown]
# Per trovare la quantità di denaro prestata in riferimento ad ogni anno serviranno: inzio, fine, l'ammontare e la durata dei prestiti. Si è scelto di non prendere in considerazione i casi in cui `disburse_time` sia superiore a  `planned_expiration_time`.

# %%
anno1 = [anno.year for anno in loans['disburse_time']]

# %%
anno2 = [anno.year for anno in loans['planned_expiration_time']]

# %%
amounts = list(loans['loan_amount'])

# %%
durata = loans['duration']

# %% [markdown]
# Scorro tutte le righe del dataset, se la durata del prestito non è negativa si identificano due possibilità: l'anno dell'esborso è lo stesso della data di scadenza, `disburse_time` e `planned_expiration_time` cadono in anni differenti. Nel primo caso l'importo viene ripartito totalmente all'anno in corso, nel secondo viene creata una lista contenente tutto il range di anni del prestito e l'ammontare viene distribuito proporzionalmente al numero di giorni.

# %%
lanno=[]
limporto=[]

# %%
for i in range(len(loans)):
    importo=amounts[i]
    anno_in=anno1[i]
    anno_fin=anno2[i]
    giorni_prestito=durata[i].days
    if giorni_prestito >= 0:
        if anno_in==anno_fin:
            lanno.append(anno_in)
            limporto.append(importo)
        else:
            anni=list(range(anno_in,anno_fin+1))  
    
            anno=anni[0]
            if anno in bisestili:
                ga=366-loans['disburse_time'][i].dayofyear
            else:    
                ga=365-loans['disburse_time'][i].dayofyear
            ia=(ga*importo)/giorni_prestito
            lanno.append(anno)
            limporto.append(ia)

            for j in range(1,len(anni)-1):
                anno=anni[j]
                if anno in bisestili:
                    ia=(366*importo)/giorni_prestito
                else:
                    ia=(365*importo)/giorni_prestito
                lanno.append(anno)
                limporto.append(ia)

            anno=anni[-1]
            ga=loans['planned_expiration_time'][i].dayofyear
            ia=(ga*importo)/giorni_prestito
            lanno.append(anno)
            limporto.append(ia)

# %%
anno_importo = pd.DataFrame()
anno_importo['Anno'] = lanno
anno_importo['Importo'] = limporto

# %%
pd.DataFrame(anno_importo.groupby('Anno')['Importo'].sum())
# Out:
#            Importo
# Anno
# 2011  6.299118e+05
# 2012  1.130523e+08
# 2013  1.235038e+08
# 2014  1.506786e+08
# 2015  1.552877e+08
# 2016  1.542358e+08
# 2017  1.657267e+08
# 2018  5.079946e+06

# %%
end = time.time()

print("Durata: {} minuti".format(int((end-start)/60)))
# Out:
# Durata: 4 minuti
